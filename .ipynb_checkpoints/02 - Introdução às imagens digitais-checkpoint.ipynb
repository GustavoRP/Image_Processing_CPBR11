# %% [markdown]
# # Introdução às imagens digitais

# %% [markdown]
# Uma imagem digital pode ser representada por uma matriz bidimensional, onde os seus elementos são chamados de pixels (picture elements).
#
# Iremos utilizar a matriz disponível no ndarray NumPy para representar as imagens. A vantagem é que todas as operações disponíveis para processamento matricial podem ser utilizados como processamento de imagens.
#
# Vamos trabalhar basicamente em 3 tipos representações das imagens:
#
# ** Binárias ** = cada pixel pode ter o valor True ou False
#
# ** uint8 ** = (mais utilizada) cada pixel pode assumir números inteiros entre 0 - 255
#
# ** float ** = cada pixel contém um valor entre 0.0 e 1.0

# %% [markdown]
# ## Leitura de Imagens

# %%
# https://matplotlib.org/2.0.2/users/image_tutorial.html

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('figures/cameraman.tif')

# %% [markdown]
# ### Exibindo a imagem como array

# %%
print("number of rows = ", img.shape[0])
print("number of cols = ", img.shape[1])
print("number of dimensions = ", img.ndim)
print("shape = ", img.shape)
print("datatype = ", img.dtype )
print("img.max()", img.max())
print("img.min()", img.min())

print(img)
# Out:
# number of rows =  256
# number of cols =  256
# number of dimensions =  2
# shape =  (256, 256)
# datatype =  uint8
# img.max() 251
# img.min() 0
# [[169 168 174 ..., 194 191 193]
#  [174 175 176 ..., 188 186 186]
#  [171 178 172 ..., 195 188 191]
#  ...,
#  [178 183 183 ..., 144 186 174]
#  [187 180 157 ..., 148 183 152]
#  [169 170 160 ..., 160 198 165]]

# %% [markdown]
# ## Plotando a imagem

# %%
imgplot = plt.imshow(img, 'gray')
plt.show()

# %% [markdown]
# ## Convertendo a imagem para float

# %%
img_float = img / 255.

# %%
print("number of rows = ", img_float.shape[0])
print("number of cols = ", img_float.shape[1])
print("number of dimensions = ", img_float.ndim)
print("shape = ", img_float.shape)
print("datatype = ", img_float.dtype )
print("img.max()", img_float.max())
print("img.min()", img_float.min())

print(img_float)
# Out:
# number of rows =  256
# number of cols =  256
# number of dimensions =  2
# shape =  (256, 256)
# datatype =  float64
# img.max() 0.98431372549
# img.min() 0.0
# [[ 0.6627451   0.65882353  0.68235294 ...,  0.76078431  0.74901961
#    0.75686275]
#  [ 0.68235294  0.68627451  0.69019608 ...,  0.7372549   0.72941176
#    0.72941176]
#  [ 0.67058824  0.69803922  0.6745098  ...,  0.76470588  0.7372549
#    0.74901961]
#  ...,
#  [ 0.69803922  0.71764706  0.71764706 ...,  0.56470588  0.72941176
#    0.68235294]
#  [ 0.73333333  0.70588235  0.61568627 ...,  0.58039216  0.71764706
#    0.59607843]
#  [ 0.6627451   0.66666667  0.62745098 ...,  0.62745098  0.77647059
#    0.64705882]]

# %%
imgplot = plt.imshow(img_float, 'gray')
plt.show()

# %% [markdown]
# ## Binarizando a imagem

# %%
threshold = 0.3
img_BW = img_float<threshold

# %%
print("number of rows = ", img_BW.shape[0])
print("number of cols = ", img_BW.shape[1])
print("number of dimensions = ", img_BW.ndim)
print("shape = ", img_BW.shape)
print("datatype = ", img_BW.dtype )
print("img.max()", img_BW.max())
print("img.min()", img_BW.min())

print(img_BW)
# Out:
# number of rows =  256
# number of cols =  256
# number of dimensions =  2
# shape =  (256, 256)
# datatype =  bool
# img.max() True
# img.min() False
# [[False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  ...,
#  [False False False ..., False False False]
#  [False False False ..., False False False]
#  [False False False ..., False False False]]

# %%
imgplot = plt.imshow(img_BW, 'gray')
plt.show()

# %% [markdown]
# # Imagens coloridas
#
# A difereça entre as imagens em tons de cinza e das imagens coloridas é que esta útima possui canais de cores.
# O padrão mais utilizado é o RGB (Red, Green, Blue), que é exatamente o padrão usado nos monitores.
#
# Com a adição do canal de cores, o array que representa a imagem agora passa a ter uma terceira dimensão.

# %%
img=mpimg.imread('figures/Lenna.png')

# %%
print("number of rows = ", img.shape[0])
print("number of cols = ", img.shape[1])
print("number of dimensions = ", img.ndim)
print("shape = ", img.shape)
print("datatype = ", img.dtype )
print("img.max()", img.max())
print("img.min()", img.min())

print(img)
# Out:
# number of rows =  512
# number of cols =  512
# number of dimensions =  3
# shape =  (512, 512, 3)
# datatype =  float32
# img.max() 1.0
# img.min() 0.0117647
# [[[ 0.88627452  0.53725493  0.49019608]
#   [ 0.88627452  0.53725493  0.49019608]
#   [ 0.87450981  0.53725493  0.52156866]
#   ...,
#   [ 0.90196079  0.58039218  0.47843137]
#   [ 0.86666667  0.50980395  0.43137255]
#   [ 0.78431374  0.3882353   0.35294119]]
#
#  [[ 0.88627452  0.53725493  0.49019608]
#   [ 0.88627452  0.53725493  0.49019608]
#   [ 0.87450981  0.53725493  0.52156866]
#   ...,
#   [ 0.90196079  0.58039218  0.47843137]
#   [ 0.86666667  0.50980395  0.43137255]
#   [ 0.78431374  0.3882353   0.35294119]]
#
#  [[ 0.88627452  0.53725493  0.49019608]
#   [ 0.88627452  0.53725493  0.49019608]
#   [ 0.87450981  0.53725493  0.52156866]
#   ...,
#   [ 0.90196079  0.58039218  0.47843137]
#   [ 0.86666667  0.50980395  0.43137255]
#   [ 0.78431374  0.3882353   0.35294119]]
#
#  ...,
#  [[ 0.32941177  0.07058824  0.23529412]
#   [ 0.32941177  0.07058824  0.23529412]
#   [ 0.36078432  0.10588235  0.22745098]
#   ...,
#   [ 0.67843139  0.28627452  0.32941177]
#   [ 0.67450982  0.26666668  0.29803923]
#   [ 0.69411767  0.24313726  0.30980393]]
#
#  [[ 0.32156864  0.08627451  0.22352941]
#   [ 0.32156864  0.08627451  0.22352941]
#   [ 0.3764706   0.1254902   0.24313726]
#   ...,
#   [ 0.7019608   0.27450982  0.30980393]
#   [ 0.70980394  0.27843139  0.31764707]
#   [ 0.72549021  0.29019609  0.31764707]]
#
#  [[ 0.32156864  0.08627451  0.22352941]
#   [ 0.32156864  0.08627451  0.22352941]
#   [ 0.3764706   0.1254902   0.24313726]
#   ...,
#   [ 0.7019608   0.27450982  0.30980393]
#   [ 0.70980394  0.27843139  0.31764707]
#   [ 0.72549021  0.29019609  0.31764707]]]

# %%
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## Exibindo cada canal separadamente

# %%
img_R = img[:,:,0]
img_G = img[:,:,1]
img_B = img[:,:,2]

# %%
plt.figure(figsize=(24, 12))

plt.subplot(1, 3, 1)
plt.imshow(img_R, 'gray')

plt.subplot(1, 3, 2)
plt.imshow(img_G, 'gray')

plt.subplot(1, 3, 3)
plt.imshow(img_B, 'gray')

plt.show()

# %% [markdown]
# ## Convertendo a imagem para tons de cinza

# %%
img_gray = (img_R + img_G + img_B/2) / 3

# %%
print("number of rows = ", img_gray.shape[0])
print("number of cols = ", img_gray.shape[1])
print("number of dimensions = ", img_gray.ndim)
print("shape = ", img_gray.shape)
print("datatype = ", img_gray.dtype )
print("img.max()", img_gray.max())
print("img.min()", img_gray.min())

print(img_gray)
# Out:
# number of rows =  512
# number of cols =  512
# number of dimensions =  2
# shape =  (512, 512)
# datatype =  float32
# img.max() 0.794771
# img.min() 0.110458
# [[ 0.55620915  0.55620915  0.55751634 ...,  0.57385623  0.53071898
#    0.44967321]
#  [ 0.55620915  0.55620915  0.55751634 ...,  0.57385623  0.53071898
#    0.44967321]
#  [ 0.55620915  0.55620915  0.55751634 ...,  0.57385623  0.53071898
#    0.44967321]
#  ...,
#  [ 0.17254902  0.17254902  0.19346406 ...,  0.3764706   0.3633987
#    0.3640523 ]
#  [ 0.17320262  0.17320262  0.20784314 ...,  0.37712419  0.38235295
#    0.39150324]
#  [ 0.17320262  0.17320262  0.20784314 ...,  0.37712419  0.38235295
#    0.39150324]]

# %%
imgplot = plt.imshow(img_gray, 'gray')
plt.show()

# %%
img_C = np.array([[img_R, img_G, img_B]]).reshape(3,512,512)
print("shape = ", img_C.shape)
imgplot = plt.imshow(img_C, 'gray')
plt.show()
# Out:
# shape =  (3, 512, 512)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-d6dfe840050e> in <module>()
#       1 img_C = np.array([[img_R, img_G, img_B]]).reshape(3,512,512)
#       2 print("shape = ", img_C.shape)
# ----> 3 imgplot = plt.imshow(img_C, 'gray')
#       4 plt.show()
#
# C:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3155                         filternorm=filternorm, filterrad=filterrad,
#    3156                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3157                         **kwargs)
#    3158     finally:
#    3159         ax._hold = washold
#
# C:\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5122                               resample=resample, **kwargs)
#    5123
# -> 5124         im.set_data(X)
#    5125         im.set_alpha(alpha)
#    5126         if im.get_clip_path() is None:
#
# C:\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     598         if (self._A.ndim not in (2, 3) or
#     599                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 600             raise TypeError("Invalid dimensions for image data")
#     601
#     602         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %% [markdown]
# # Modificações simples nas imagens

# %% [markdown]
# ### Quadriculado sobreposto na imagem

# %%
img=mpimg.imread('figures/CP.jpg')
img_gray = img[:,:,1]

# %%
print("number of rows = ", img_gray.shape[0])
print("number of cols = ", img_gray.shape[1])
print("number of dimensions = ", img_gray.ndim)
print("shape = ", img_gray.shape)
print("datatype = ", img_gray.dtype )
print("img.max()", img_gray.max())
print("img.min()", img_gray.min())

imgplot = plt.imshow(img_gray, 'gray')
plt.show()
# Out:
# number of rows =  110
# number of cols =  190
# number of dimensions =  2
# shape =  (110, 190)
# datatype =  uint8
# img.max() 189
# img.min() 0

# %%
import numpy as np

delta = 2

g = np.copy(img_gray)
g[::delta,:] = 255
g[:,::delta] = 255

# %%
imgplot = plt.imshow(g, 'gray')
plt.show()

# %% [markdown]
# ## slicing

# %%
img=mpimg.imread('figures/CP.jpg')
img_gray = img[:,:,1]

# %%
slice_y = 1
slice_x = -1

g = np.zeros(img_gray.shape)
g[::slice_x,:] = 1
g[:,::slice_y] = 1

g = g * img_gray

imgplot = plt.imshow(g, 'gray')
plt.show()

# %%
# Parcela descartada
imgplot = plt.imshow(img_gray - g, 'gray')
plt.show()

# %%
img_sliced = img_gray[::slice_x,::slice_y]

imgplot = plt.imshow(img_sliced.T, 'gray')
plt.show()
